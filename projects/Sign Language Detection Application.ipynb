# %% [markdown]
# 1.Import and Install Dependancies.

# %%
# !pip install tensorflow==2.5.2 tensorflow-gpu==2.5.2 opencv-python mediapipe sklearn matplotlib
# Out:
# Requirement already satisfied: tensorflow==2.5.2 in c:\users\tanishq\anaconda3\lib\site-packages (2.5.2)
# Requirement already satisfied: tensorflow-gpu==2.5.2 in c:\users\tanishq\anaconda3\lib\site-packages (2.5.2)
# Requirement already satisfied: opencv-python in c:\users\tanishq\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: mediapipe in c:\users\tanishq\anaconda3\lib\site-packages (0.8.11)
# Requirement already satisfied: sklearn in c:\users\tanishq\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: matplotlib in c:\users\tanishq\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (3.3.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (1.12)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (1.6.3)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (3.1.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (3.7.4.3)
# Requirement already satisfied: six~=1.15.0 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (1.15.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (2.5.0.dev2021032900)
# Requirement already satisfied: wheel~=0.35 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (0.37.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (1.1.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (1.12.1)
# Requirement already satisfied: gast==0.4.0 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (0.4.0)
# Requirement already satisfied: absl-py~=0.10 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (0.15.0)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (1.34.1)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (3.19.6)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (2.5.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (0.2.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (1.19.5)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (1.1.2)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorflow==2.5.2) (2.10.1)
# Requirement already satisfied: opencv-contrib-python in c:\users\tanishq\anaconda3\lib\site-packages (from mediapipe) (4.6.0.66)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\tanishq\anaconda3\lib\site-packages (from mediapipe) (21.2.0)
# Requirement already satisfied: scikit-learn in c:\users\tanishq\anaconda3\lib\site-packages (from sklearn) (0.24.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tanishq\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tanishq\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\tanishq\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tanishq\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\tanishq\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (1.8.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (58.0.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (2.0.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (2.11.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\tanishq\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (2.26.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\tanishq\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.2) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tanishq\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.2) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tanishq\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\tanishq\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.2) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\tanishq\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.2) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\tanishq\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.2) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\tanishq\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.2) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tanishq\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.2) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tanishq\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.2) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\tanishq\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tanishq\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.2) (3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\tanishq\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.2) (3.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tanishq\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\tanishq\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.7.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\tanishq\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.1.0)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time 
import mediapipe as mp

# %% [markdown]
# 2.Keypoints using MP Holistics

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('f'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %% [markdown]
#  len(results.face_landmarks.landmark)

# %%
results
# Out:
# mediapipe.python.solution_base.SolutionOutputs

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# 3.Extract Keypoint Values

# %%
results.pose_landmarks
# Out:
# landmark {
#   x: 0.573114275932312
#   y: 0.624006986618042
#   z: -1.0736310482025146
#   visibility: 0.9996674060821533
# }
# landmark {
#   x: 0.61067795753479
#   y: 0.5383942723274231
#   z: -1.0138581991195679
#   visibility: 0.9992436766624451
# }
# landmark {
#   x: 0.6309646964073181
#   y: 0.5392606258392334
#   z: -1.0138919353485107
#   visibility: 0.9993380904197693
# }
# landmark {
#   x: 0.6523550748825073
#   y: 0.5414320826530457
#   z: -1.0141254663467407
#   visibility: 0.999116063117981
# }
# landmark {
#   x: 0.5451178550720215
#   y: 0.5364035367965698
#   z: -1.0092284679412842
#   visibility: 0.9993546009063721
# }
# landmark {
#   x: 0.5231906771659851
#   y: 0.5345986485481262
#   z: -1.0082285404205322
#   visibility: 0.9994980692863464
# }
# landmark {
#   x: 0.5031943917274475
#   y: 0.5337934494018555
#   z: -1.0086023807525635
#   visibility: 0.9994556903839111
# }
# landmark {
#   x: 0.6932621598243713
#   y: 0.5750665068626404
#   z: -0.589771032333374
#   visibility: 0.9991629123687744
# }
# landmark {
#   x: 0.4829440116882324
#   y: 0.5646504163742065
#   z: -0.5395208597183228
#   visibility: 0.9996277093887329
# }
# landmark {
#   x: 0.6098061203956604
#   y: 0.7054483294487
#   z: -0.9101306796073914
#   visibility: 0.999658465385437
# }
# landmark {
#   x: 0.5328362584114075
#   y: 0.7024699449539185
#   z: -0.8971434831619263
#   visibility: 0.9997616410255432
# }
# landmark {
#   x: 0.8694106340408325
#   y: 0.9631310701370239
#   z: -0.3435155153274536
#   visibility: 0.9950534701347351
# }
# landmark {
#   x: 0.3293493688106537
#   y: 0.9759393334388733
#   z: -0.37852853536605835
#   visibility: 0.9983316659927368
# }
# landmark {
#   x: 0.9823261499404907
#   y: 1.4285027980804443
#   z: -0.33764031529426575
#   visibility: 0.07377757877111435
# }
# landmark {
#   x: 0.21238009631633759
#   y: 1.4155455827713013
#   z: -0.4092279076576233
#   visibility: 0.2623058259487152
# }
# landmark {
#   x: 0.9524227976799011
#   y: 1.7843934297561646
#   z: -0.7280115485191345
#   visibility: 0.0228534247726202
# }
# landmark {
#   x: 0.22386734187602997
#   y: 1.7901076078414917
#   z: -1.0736396312713623
#   visibility: 0.07359848916530609
# }
# landmark {
#   x: 0.9771003723144531
#   y: 1.9128504991531372
#   z: -0.8681333661079407
#   visibility: 0.03285350278019905
# }
# landmark {
#   x: 0.18982163071632385
#   y: 1.9263380765914917
#   z: -1.2415863275527954
#   visibility: 0.08518707752227783
# }
# landmark {
#   x: 0.9212396740913391
#   y: 1.902955412864685
#   z: -0.9370707273483276
#   visibility: 0.055226005613803864
# }
# landmark {
#   x: 0.2524864673614502
#   y: 1.9120380878448486
#   z: -1.3377869129180908
#   visibility: 0.139085054397583
# }
# landmark {
#   x: 0.8997265696525574
#   y: 1.848960041999817
#   z: -0.8011249303817749
#   visibility: 0.05415504053235054
# }
# landmark {
#   x: 0.27790728211402893
#   y: 1.858177661895752
#   z: -1.1385581493377686
#   visibility: 0.12542197108268738
# }
# landmark {
#   x: 0.7714030742645264
#   y: 1.844626784324646
#   z: -0.07988704741001129
#   visibility: 0.000289257790427655
# }
# landmark {
#   x: 0.41416749358177185
#   y: 1.8439980745315552
#   z: 0.08581056445837021
#   visibility: 0.00028065487276762724
# }
# landmark {
#   x: 0.7666878700256348
#   y: 2.5899083614349365
#   z: -0.05402301624417305
#   visibility: 0.000644901767373085
# }
# landmark {
#   x: 0.4388968050479889
#   y: 2.589064359664917
#   z: 0.19047310948371887
#   visibility: 0.00025040318723767996
# }
# landmark {
#   x: 0.7716856002807617
#   y: 3.2725627422332764
#   z: 0.6793873906135559
#   visibility: 9.296108328271657e-05
# }
# landmark {
#   x: 0.4669777452945709
#   y: 3.256788730621338
#   z: 0.7539799809455872
#   visibility: 1.0680153536668513e-05
# }
# landmark {
#   x: 0.7804244756698608
#   y: 3.38638973236084
#   z: 0.7107900381088257
#   visibility: 6.700802623527125e-05
# }
# landmark {
#   x: 0.46838945150375366
#   y: 3.366802930831909
#   z: 0.7907580733299255
#   visibility: 3.30222028424032e-05
# }
# landmark {
#   x: 0.7182011604309082
#   y: 3.4855406284332275
#   z: -0.008007817901670933
#   visibility: 9.46308282436803e-05
# }
# landmark {
#   x: 0.5165494084358215
#   y: 3.4613919258117676
#   z: 0.03726191446185112
#   visibility: 9.415973181603476e-05
# }

# %%
for res in results.pose_landmarks.landmark:
     test=np.array([res.x,res.y,res.z, res.visibility])

# %%
test
# Out:
# array([5.16549408e-01, 3.46139193e+00, 3.72619145e-02, 9.41597318e-05])

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten()  if results.face_landmarks  else np.zeros(1404)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.57311428,  0.62400699, -1.07363105, ...,  0.        ,
#         0.        ,  0.        ])

# %%
468*3+33*4+21*3+21*3
# Out:
# 1662

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.57311428,  0.62400699, -1.07363105, ...,  0.        ,
#         0.        ,  0.        ])

# %% [markdown]
# 4.Setup Folders for Collection

# %%
#path for exported data basically our numpy arrays.
DATA_PATH=os.path.join('MP_Data')
#actions which we will try to detect.
actions=np.array(['Hi','Bye','Thanks','I Love You!'])
#10 videos worth of data.
no_sequences=10
# videos are going to be about 10 frames in length.
sequence_length=10

# %%
for action in actions:
    for sequence in range(no_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH,action,str(sequence)))
        except:
                pass

# %% [markdown]
# 5. Collecting Keypoints for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(start_folder, start_folder+no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# 6.

# %% [markdown]
# 7.

# %% [markdown]
# 8.

# %% [markdown]
# 9.

# %% [markdown]
# 10.
